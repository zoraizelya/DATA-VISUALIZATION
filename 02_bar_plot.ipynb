# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
flower=sns.load_dataset("iris")
flower

# draw a line plot 
sns.barplot(x="species",y="sepal_width",data=flower)
plt.title("Flowers Plot")

# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
flower=sns.load_dataset("iris")
flower

# draw a line plot 
sns.barplot(x="species",y="petal_length",data=flower)
plt.title("Flowers Plot")

# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a line plot 
sns.barplot(x="who",y="alone",data=titanic)
plt.title("Flowers Plot")

# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a line plot 
sns.barplot(x="who",y="alone",hue="sex",data=titanic)
plt.title("Flowers Plot")

# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a BAR plot with order
sns.barplot(x="sex",y="alone",hue="who",data=titanic,order=["female","male"])
plt.title("Flowers Plot")
# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a BAR plot with order + color palette
sns.barplot(x="sex",y="alone",hue="who",data=titanic,order=["female","male"],color="green")
plt.title("Flowers Plot")
# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a BAR plot with order
sns.barplot(x="sex",y="alone",hue="who",data=titanic,order=["female","male"],color="red",ci=None, palette="pastel")
plt.title("Flowers Plot")
# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
# we needs to import a library for estimator
import numpy
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a BAR plot with order
sns.barplot(x="class",y="fare",hue="sex",data=titanic,estimator=mean)
plt.title("Flowers Plot")
# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
# we needs to import a library for estimator
import numpy
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a bAR plot with order
# saturation is managing the color intensity
sns.barplot(x="class",y="fare",hue="sex",data=titanic,estimator=mean,saturation=1)
plt.title("Flowers Plot")
# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
# we needs to import a library for estimator
import numpy
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a Horizontal with order
# saturation is managing the color intensity
sns.barplot(x="fare",y="class",hue="sex",data=titanic,estimator=mean,saturation=2)
plt.title("Flowers Plot")
# Style adding 
sns.set_style("whitegrid")

# %%
import seaborn as sns
# we needs to import a library for estimator
import numpy
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a BAR plot with order
# saturation is managing the color intensity
sns.barplot(x="class",y="fare",data=titanic,
            linewidth=3,facecolor=(1,1,1,0),
            errcolor=".6",edgecolor=".2")
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
import seaborn as sns
# we needs to import a library for estimator
import numpy
import matplotlib.pyplot as plt
# load data set
titanic=sns.load_dataset("titanic")
titanic

# draw a BAR plot with order
# saturation is managing the color intensity
sns.barplot(x="sex",y="fare",hue="class",data=titanic,
            linewidth=3,facecolor=(0.1,0.2,0.1,0.1),
            errcolor=".6",edgecolor=".2")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>
